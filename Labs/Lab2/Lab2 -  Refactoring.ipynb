# %% [markdown]
# # Lab 2 - Refactoring  - Alexander Land & Maggie Tapia
# ## Refactoring is:
#
# Refactoring is the process of restructuring or rewriting code, while not changing its original functionality. The goal of refactoring is to improve internal code by making many small changes without altering the code's external behavior.
#
# It is easier said than done.

# %% [markdown]
# ### Part 1 - Warm-up
#
# You will refactor the following code:

# %%
#stolen from https://realpython.com/python-refactoring/
#yes you can go there and look at what they did no do it yourself
x = 5
value = input("Enter a number: ")
y = int(value)
if x < y:
    print(f"{x} is less than {y}")
elif x == y:
    print(f"{x} is equal to {y}")
else:
    print(f"{x} is more than {y}")
# Out:
# Enter a number:  1
# 5 is more than 1

# %%
# put your refactored code here
x = 5; y = int(input("enter a number: "))
equality = "is equal to" if x == y else "is less than" if x < y else "is more than"
print(f"{x} {equality} {y}")
# Out:
# 5 is more than 4

# %% [markdown]
# ## Part 2
# Refactor the following

# %%
def a(x, y):
    '''
    if x == "wizard":
        if y == "fireball":
            return "casts fireball"
        elif y == "lightning":
            return "casts lightning"
        else:
            return "does nothing"
   ''' 

    if x == "wizard":
        return "casts fireball" if  y == "fireball" else "casts lightning" if y == "lightning" else "do nothing"

    '''
    if x == "warrior":
        if y == "slash":
            return "slashes with sword"
        elif y == "bash":
            return "bashes with shield"
        else:
            return "does nothing"
    else:
        return "does nothing"
    '''
    if x == "warrior":
        return "slashes with sword" if y == "slash" else "bashes with shield" if y == "bash" else "does nothing"


def b(z):
    '''
    for i in range(10):
        if z == "dragon":
            return "fights dragon"
        elif z == "goblin":
            return "fights goblin"
        elif z == "orc":
            return "fights orc"
        else:
            return "does nothing"
    '''

    return "fights dragon" if z == "dragon" else "fights goblin" if z == "goblin" else "fights orc" if z == "orc" else "does nothing"


def c():
    '''
    for i in range(5):
        print("exploring dungeon")
    for j in range(5):
        print("finding treasure")
'''
    print("exploring dungeon\n"*5 + "finding treasure\n"*5)
    

def main():
    print(a("wizard", "fireball"))
    print(a("warrior", "slash"))
    print(b("dragon"))
    c()



if __name__ == "__main__":
    main()
# Out:
# casts fireball
# slashes with sword
# fights dragon
# exploring dungeon
# exploring dungeon
# exploring dungeon
# exploring dungeon
# exploring dungeon
# finding treasure
# finding treasure
# finding treasure
# finding treasure
# finding treasure

# %%
# put your refactored code here
'''
def a(x, y):

    if x == "wizard":
        return "casts fireball" if  y == "fireball" else "casts lightning" if y == "lightning" else "do nothing"

    if x == "warrior":
        return "slashes with sword" if y == "slash" else "bashes with shield" if y == "bash" else "does nothing"
'''
#code commented out is ugly cause it is shortened too much and is unreadable

def a(inCharType, inOffense):
    wizardSpells = ["fireball","lightning"]
    warriorAttacks = ["slash","bash"]

    if inCharType == "wizard":
        if inOffense in wizardSpells:
            return "casts " + inOffense
        
    elif inCharType == "warrior":
        if inOffense in warriorAttacks:
            return "casts " + inOffense
    return "does nothing"
        
        
'''
def b(z):
    return "fights dragon" if z == "dragon" else "fights goblin" if z == "goblin" else "fights orc" if z == "orc" else "does nothing"
'''
def b(inEnemies):
    Enemies = ["dragon", "goblin", "orc"]
    if inEnemies in Enemies:
        return "fights " + inEnemies


def c():
    print("exploring dungeon\n"*5 + "finding treasure\n"*5)
    # idk what this function is supposed to do so I just made the same output in a simpler one line print

def main():
    print(a("wizard", "fireball"))
    print(a("warrior", "slash"))
    print(b("dragon"))
    c()



if __name__ == "__main__":
    main()
# Out:
# casts fireball
# casts slash
# fights dragon
# exploring dungeon
# exploring dungeon
# exploring dungeon
# exploring dungeon
# exploring dungeon
# finding treasure
# finding treasure
# finding treasure
# finding treasure
# finding treasure

# %% [markdown]
# # Part 3
# Refactor your partners lab 1 code so it is a clean function. Look at part 4 and see how you can adapt the code to fit project one.

# %%
# Alexander Land & Maggie Tapia 
import random
import os

os.system('cls')
#clears screen


def rollDice():
    return random.randint(1,6)
    #idk any other way to write this


def printStats(playerWinLoss):
    wins = 0
    ties = 0
    for round in playerWinLoss: #increments for wins and ties IDK if if/elif is neater than ternaries
        wins += 1 if round == 1 else 0
        ties += 1 if round == 2 else 0

    winrate = wins/len(playerWinLoss)

    print("YOUR STATS\n----------")
    print("you won", wins, "games")
    print("you tied", ties,"games")
    print("your winrate is ", winrate, "\n")

# second method is reduntant but is added because 
# prof powers asked us to calculate stats a different way
def printStatsMethod2(ListofmyRolls,ListofPuterRolls):
    wins = 0
    losses = 0
    ties = 0

    for i in range(0,len(ListofmyRolls)): #i iterates from 0 to the number of games played
        #compares each game to check for win or loss then increments

        #elif the ternaries read easy but I don't think are as good as elifs so I didn't change it to these
        '''
        wins +=     1 if ListofmyRolls[i] > ListofPuterRolls[i] else 0
        losses +=   1 if ListofmyRolls[i] < ListofPuterRolls[i] else 0
        ties +=     1 if ListofmyRolls[i] == ListofPuterRolls[i] else 0
        '''
        if ListofmyRolls[i] > ListofPuterRolls[i]: 
            wins += 1
        elif ListofmyRolls[i] < ListofPuterRolls[i]:
            losses += 1
        else:
            ties += 1
    
    winrate = wins/(wins + losses + ties) 

    #also chose not to condense print statements because it 
    # makes it easy to see what each line will print
    print("YOUR STATS Method 2\n----------")
    print("you won", wins, "games")
    print("you tied", ties,"games")
    print("your winrate is ", winrate, "\n")


def main():
    print("Welcome to the Dice Rolling Game!")
    print("You and Puter will each roll a dice, and the one with the higher number wins.\n")
    #we stole the intro text 

    playerWinLoss = []
        #initialized win loss array for first method

    ListofPuterRolls = []
    ListofmyRolls = []
        #lists for method two stats


    while True:
        input("Press Enter to roll")

        myRoll = rollDice()
        ListofmyRolls.append(myRoll) #stores each roll for stats method 2

        PuterRoll = rollDice()
        ListofPuterRolls.append(PuterRoll)

        print("you rolled:", myRoll)
        print("Puter rolled:", PuterRoll)

        if myRoll > PuterRoll:
            print("win\n")
            playerWinLoss.append(1)

        elif PuterRoll > myRoll:
            print("lose\n")
            playerWinLoss.append(0)

        else:
            print("tie\n")
            playerWinLoss.append(2)

        #print("")  # put the linebreaks in the print statements above to 
        # get rid of random empty print statement

        

        playAgain = input("would u like to play again (y/n):").lower()

        if playAgain !="y": # if y isn't pressed, while loop gets broken and stats are shown
            break

        

    printStats(playerWinLoss)
    #print("")  # also removed this print by adding new line above
    printStatsMethod2(ListofmyRolls, ListofPuterRolls)



if __name__ == "__main__":
    main()

# this program is simple so its hard for me to find ways to simplify it more.
# If I were to add more complexity such as adding another computer player
# there would be more room for me to find neat ways to refactor.

# as with the number of players it would be better for me to create a new list
# a system for creating a new list for each player and a system that could take
# any number of these players and add calculate their stats.
# Out:
# Welcome to the Dice Rolling Game!
# You and Puter will each roll a dice, and the one with the higher number wins.
# you rolled: 1
# Puter rolled: 1
# tie
#
# you rolled: 5
# Puter rolled: 3
# win
#
# you rolled: 4
# Puter rolled: 1
# win
#
# you rolled: 4
# Puter rolled: 4
# tie
#
# you rolled: 2
# Puter rolled: 4
# lose
#
# you rolled: 3
# Puter rolled: 2
# win
#
# you rolled: 2
# Puter rolled: 5
# lose
#
# YOUR STATS
# ----------
# you won 3 games
# you tied 2 games
# your winrate is  0.42857142857142855
#
# YOUR STATS Method 2
# ----------
# you won 3 games
# you tied 2 games
# your winrate is  0.42857142857142855

# %% [markdown]
# ## Part 4 - take home but start in class
# # Project #1  introduction
#
#
# Your task is to develop a text-based video game focusing on the player profile, inventory system, and combat mechanics. Create a realistic player character with at least 10 inventory items, each with a description and an associated trait. Enjoy the process!
#
# Incorporate all the concepts we've covered so far, including files (read and write), JSON, operators, lists, optional tuples, functions, modules, and classes.
#
# ### Requirements:
# - **Player Type Selection**: Allow players to choose their character type. Set attributes based on the choice (e.g., wizard: magic = 10, knight: magic = 0).
# - **Inventory Display**: Implement a function to show the player's inventory.
# - **Item Details**: Write a function to provide detailed information about an inventory item (e.g., Knife: "forged in the depths of Polymar", +5 magic, edged weapon, one-handed).
#   - Bonus: Calculate bonuses when equipping and unequipping items.
# - **Inventory Management**: Create functions to add and remove items from the inventory.
# - **Persistence**: Ensure the game can save and reload the player's character using files.
#
# Focus on building the player and inventory system for your text-based adventure game (similar to Zork). The map and gameplay can be developed later.
#
# ### Game Features:
# - **Player Profile**: Include player stats.
# - **Inventory System**: Implement a bag to hold items.
# - **Items**: Include 10 items, each with a description and trait (e.g., +5 magic).
# - **Concepts**: Utilize functions, loops, arrays, classes, and constants. You may also use files and structs if desired.
# - **Player Type Selection**: Allow players to choose their character type and set attributes accordingly (e.g., wizard: magic = 10, knight: magic = 0).
# - **Inventory Display**: Implement a function to show the player's inventory.
# - **Code Quality**: Keep your code clean and consider various player needs, as this project will be handed off to a partner for further development.

# %% [markdown]
# # Project 1 - Part 1
# Spend time planning out your code. You may work with your partner to plan out your code. How would you like your game to play?
#
# Use a UML planner like:
#
#
# https://miro.com/
